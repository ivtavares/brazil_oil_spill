# %%
import pandas as pd
import numpy as np
from datetime import datetime
pd.options.display.max_rows = 999

# %% [markdown]
# # Base de dados: Manchas de óleo.

# %%
oilstory_df = pd.read_csv('oilstory.csv')

# %%
oilstory_df.head()
# Out:
#          Localidade Município Estado Avistamento
# 0        Praia Bela   Pitimbu     PB        30/8
# 1  Praia de Tambaba   Pitimbu     PB        30/8
# 2     Praia de Acau   Pitimbu     PB        30/8
# 3  Praia de Gramame     Conde     PB        30/8
# 4   Praia de Jacumã     Conde     PB        30/8

# %% [markdown]
# ## Renomear colunas

# %%
oilstory_df.columns = ['localidade', 'municipio', 'estado', 'avistamento']

# %% [markdown]
# ## Modificar data para formato correto

# %%
oilstory_df['data_avistamento'] = oilstory_df.avistamento\
                                    .apply(lambda x: datetime.
                                           strptime(
                                               x.strip()+'/2019','%d/%m/%Y'
                                           )
                                          )

# %% [markdown]
# ## Remover coluna duplicada

# %%
oilstory_df.drop(columns='avistamento', inplace=True)

# %%
oilstory_df.head()
# Out:
#          localidade municipio estado data_avistamento
# 0        Praia Bela   Pitimbu     PB       2019-08-30
# 1  Praia de Tambaba   Pitimbu     PB       2019-08-30
# 2     Praia de Acau   Pitimbu     PB       2019-08-30
# 3  Praia de Gramame     Conde     PB       2019-08-30
# 4   Praia de Jacumã     Conde     PB       2019-08-30

# %% [markdown]
# ## Modifcar nome do múnicipio para primeira letra de cada palavra ser maiúscula

# %%
oilstory_df['municipio'] = oilstory_df.municipio.str.title()

# %%
oilstory_df.head()
# Out:
#          localidade municipio estado data_avistamento
# 0        Praia Bela   Pitimbu     PB       2019-08-30
# 1  Praia de Tambaba   Pitimbu     PB       2019-08-30
# 2     Praia de Acau   Pitimbu     PB       2019-08-30
# 3  Praia de Gramame     Conde     PB       2019-08-30
# 4   Praia de Jacumã     Conde     PB       2019-08-30

# %% [markdown]
# ## Criar campo único para refêrencia

# %%
oilstory_df['municipio_estado'] = oilstory_df.municipio+'/'+oilstory_df.estado

# %%
oilstory_df.head()
# Out:
#          localidade municipio estado data_avistamento municipio_estado
# 0        Praia Bela   Pitimbu     PB       2019-08-30       Pitimbu/PB
# 1  Praia de Tambaba   Pitimbu     PB       2019-08-30       Pitimbu/PB
# 2     Praia de Acau   Pitimbu     PB       2019-08-30       Pitimbu/PB
# 3  Praia de Gramame     Conde     PB       2019-08-30         Conde/PB
# 4   Praia de Jacumã     Conde     PB       2019-08-30         Conde/PB

# %% [markdown]
# # Base de dados: Cidades Brasileiras

# %%
brazil_cities = pd.read_csv('BRAZIL_CITIES.csv',sep=';')

# %%
brazil_cities.head()
# Out:
#                   CITY STATE  CAPITAL  IBGE_RES_POP  IBGE_RES_POP_BRAS  \
# 0      Abadia De Goiás    GO        0        6876.0             6876.0
# 1  Abadia Dos Dourados    MG        0        6704.0             6704.0
# 2            Abadiânia    GO        0       15757.0            15609.0
# 3               Abaeté    MG        0       22690.0            22690.0
# 4           Abaetetuba    PA        0      141100.0           141040.0
#
#    IBGE_RES_POP_ESTR  IBGE_DU  IBGE_DU_URBAN  IBGE_DU_RURAL  IBGE_POP  ...  \
# 0                0.0   2137.0         1546.0          591.0    5300.0  ...
# 1                0.0   2328.0         1481.0          847.0    4154.0  ...
# 2              148.0   4655.0         3233.0         1422.0   10656.0  ...
# 3                0.0   7694.0         6667.0         1027.0   18464.0  ...
# 4               60.0  31061.0        19057.0        12004.0   82956.0  ...
#
#    Pu_Bank   Pr_Assets    Pu_Assets    Cars  Motorcycles  Wheeled_tractor  \
# 0      NaN         NaN          NaN  2158.0       1246.0              0.0
# 1      NaN         NaN          NaN  2227.0       1142.0              0.0
# 2      1.0  33724584.0   67091904.0  2838.0       1426.0              0.0
# 3      2.0  44974716.0  371922572.0  6928.0       2953.0              0.0
# 4      4.0  76181384.0  800078483.0  5277.0      25661.0              0.0
#
#    UBER  MAC  WAL-MART  POST_OFFICES
# 0   NaN  NaN       NaN           1.0
# 1   NaN  NaN       NaN           1.0
# 2   NaN  NaN       NaN           3.0
# 3   NaN  NaN       NaN           4.0
# 4   NaN  NaN       NaN           2.0
#
# [5 rows x 81 columns]

# %% [markdown]
# ## Definir colunas a serem utilizadas

# %%
brazil_cities_mod = brazil_cities[['CITY', 'STATE','POP_GDP', 'RURAL_URBAN', 'LONG', 'LAT', 'GDP',
                                   'GDP_CAPITA','COMP_A', 'COMP_B', 'COMP_C', 'COMP_D', 'COMP_E', 
                                   'COMP_F', 'COMP_G', 'COMP_H', 'COMP_I','COMP_J','COMP_K','COMP_L',
                                   'COMP_M','COMP_N','COMP_O','COMP_P','COMP_Q','COMP_R','COMP_S',
                                   'COMP_T','COMP_U','HOTELS']].copy()

# %%
brazil_cities_mod.head()
# Out:
#                   CITY STATE   POP_GDP      RURAL_URBAN       LONG        LAT  \
# 0      Abadia De Goiás    GO    8053.0           Urbano -49.440548 -16.758812
# 1  Abadia Dos Dourados    MG    7037.0  Rural Adjacente -47.396832 -18.487565
# 2            Abadiânia    GO   18427.0  Rural Adjacente -48.718812 -16.182672
# 3               Abaeté    MG   23574.0           Urbano -45.446191 -19.155848
# 4           Abaetetuba    PA  151934.0           Urbano -48.884404  -1.723470
#
#           GDP  GDP_CAPITA  COMP_A  COMP_B  ...  COMP_M  COMP_N  COMP_O  \
# 0      166.41    20664.57     5.0     1.0  ...    10.0    12.0     4.0
# 1      180.09    25591.70     6.0     6.0  ...    15.0    29.0     2.0
# 2   287984.49    15628.40     5.0     9.0  ...     7.0    15.0     3.0
# 3   430235.36    18250.42    18.0     1.0  ...    28.0    27.0     2.0
# 4  1249255.29     8222.36     4.0     2.0  ...    22.0    16.0     2.0
#
#    COMP_P  COMP_Q  COMP_R  COMP_S  COMP_T  COMP_U  HOTELS
# 0     6.0     6.0     1.0     5.0     0.0     0.0     NaN
# 1     9.0    14.0     6.0    19.0     0.0     0.0     NaN
# 2    11.0     5.0     1.0     8.0     0.0     0.0     1.0
# 3    15.0    19.0     9.0    27.0     0.0     0.0     NaN
# 4   155.0    33.0    15.0    56.0     0.0     0.0     NaN
#
# [5 rows x 30 columns]

# %% [markdown]
# ## Criar campo único para referência

# %%
brazil_cities_mod['municipio_estado'] = brazil_cities_mod.CITY+'/'+brazil_cities_mod.STATE

# %% [markdown]
# ## Separar apenas as cidades afetadas

# %%
vector = brazil_cities_mod.municipio_estado.isin(oilstory_df.municipio_estado.unique())

# %%
affected_cities =  brazil_cities_mod[vector]

# %%
affected_cities.head()
# Out:
#           CITY STATE  POP_GDP      RURAL_URBAN       LONG        LAT  \
# 20      Acaraú    CE  61715.0  Rural Adjacente -40.118241  -2.885311
# 95   Alcântara    MA  21667.0  Rural Adjacente -44.417013  -2.403277
# 99    Alcobaça    BA  23331.0  Rural Adjacente -39.194214 -17.518933
# 203   Amontada    CE  42508.0  Rural Adjacente -39.828823  -3.364878
# 290    Aquiraz    CE  78438.0           Urbano -38.389803  -3.906194
#
#             GDP  GDP_CAPITA  COMP_A  COMP_B  ...  COMP_N  COMP_O  COMP_P  \
# 20    580727.43     9409.83    41.0     1.0  ...    14.0     2.0    71.0
# 95    117494.58     5422.74     3.0     0.0  ...     4.0     2.0     3.0
# 99    260134.12    11149.72     7.0     0.0  ...     4.0     2.0     4.0
# 203   421576.03     9917.57     6.0     1.0  ...     4.0     3.0     9.0
# 290  2144231.95    27336.65    17.0     5.0  ...   122.0     6.0    19.0
#
#      COMP_Q  COMP_R  COMP_S  COMP_T  COMP_U  HOTELS  municipio_estado
# 20     17.0     6.0    18.0     0.0     0.0     NaN         Acaraú/CE
# 95      2.0     2.0    58.0     0.0     0.0     1.0      Alcântara/MA
# 99      0.0     2.0    16.0     0.0     0.0     NaN       Alcobaça/BA
# 203     1.0     0.0    15.0     0.0     0.0     1.0       Amontada/CE
# 290    14.0    15.0    47.0     0.0     0.0     2.0        Aquiraz/CE
#
# [5 rows x 31 columns]

# %% [markdown]
# ## Comparativo entre duas tabelas

# %%
print('Base: Mancha de Óleo: Número de Cidades: {}'.format(len(oilstory_df.municipio_estado.unique())))
print('Base: Cidades Afetadas: Número de Cidades: {}'.format(affected_cities.shape[0]))
# Out:
# Base: Mancha de Óleo: Número de Cidades: 130
# Base: Cidades Afetadas: Número de Cidades: 130

# %% [markdown]
# ## Exportando dados modificados

# %%
oilstory_df.to_csv('oilstory_mod.csv')

# %%
affected_cities.to_csv('affected_cities.csv')
